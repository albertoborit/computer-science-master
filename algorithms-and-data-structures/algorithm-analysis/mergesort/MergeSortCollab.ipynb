# %%
import matplotlib.pyplot as plt

# %%
python = [[100, 269.17], [1000, 3802.78], [2000, 5637.88], [3000, 10066.75], [4000, 11247.63], [5000, 23124.93], [6000, 24839.64], [7000, 29170.04], [8000, 27366.64], [9000, 26000.98], [10000, 33576.97], [20000, 75062.99], [30000, 97311.50 ], [40000, 127914.91], [50000, 163233.76]]

# %%
CPP = [[100, 0], [1000, 0], [2000, 0], [3000, 0], [4000, 0], [5000, 0], [6000, 1.001], [7000, 0.998], [8000, 1.000], [9000, 1.000], [10000, 1.999], [20000, 3.000], [30000, 5.003], [40000, 6.996], [50000, 8.999]]

# %%
Golang = [[100, 0.00274], [1000, 0], [2000, 0.00535], [3000, 0.00534], [4000, 0.00518], [5000, 0.00530], [6000, 0.00529], [7000, 0.00529], [8000, 0.00527], [9000, 0.00527], [10000, 2.143], [20000, 1.068], [30000, 2.682], [40000, 2.777], [50000, 2.134]]

# %%
x_valuesP = [point[0] for point in python]
y_valuesP = [point[1] for point in python]

x_valuesC = [point[0] for point in CPP]
y_valuesC = [point[1] for point in CPP]

x_valuesG = [point[0] for point in Golang]
y_valuesG = [point[1] for point in Golang]


plt.plot(x_valuesP, y_valuesP, marker='o', label="Python")
plt.plot(x_valuesC, y_valuesC, marker='x', label="C++")
plt.plot(x_valuesG, y_valuesG, marker='o', label="Golang")

# Set labels for the axes
plt.xlabel('Number of Elements')
plt.ylabel('Time in ms')

# Set title for the plot
plt.title('Merge Sort Performance')

# Show the plot
plt.show()
