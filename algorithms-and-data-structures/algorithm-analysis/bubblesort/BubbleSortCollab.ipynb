# %%
import matplotlib.pyplot as plt

# %%
python = [[100, 513], [1000, 52745], [2000, 219651], [3000, 454881], [4000, 803550], [5000, 1249860], [6000, 1819943], [7000, 2554672], [8000, 3243845], [9000, 4168516], [10000, 5245252], [20000, 21330183], [30000, 47831345], [40000, 86299938], [50000, 136370417]]

# %%
CPP = [[100, 0.999], [1000, 0.998], [2000, 1], [3000, 0], [4000, 0], [5000, 0], [6000, 0.999], [7000, 0.998], [8000, 0.999], [9000, 2.1], [10000, 0.999], [20000, 3.0], [30000, 5.0], [40000, 5.9], [50000, 10.002]]

# %%
Golang = [[100, 0], [1000, 0], [2000, 0], [3000, 0.000011], [4000, 0.00524], [5000, 0.00518], [6000, 0.00528], [7000, 0.00523], [8000, 0.00519], [9000, 0.000008], [10000, 0.00524], [20000, 1.03], [30000, 1.065], [40000, 1.57], [50000, 2.095]]

# %%
x_valuesP = [point[0] for point in python]
y_valuesP = [point[1] for point in python]

x_valuesC = [point[0] for point in CPP]
y_valuesC = [point[1] for point in CPP]

x_valuesG = [point[0] for point in Golang]
y_valuesG = [point[1] for point in Golang]


plt.plot(x_valuesP, y_valuesP, marker='o', label="Python")
plt.plot(x_valuesC, y_valuesC, marker='x', label="C++")
plt.plot(x_valuesG, y_valuesG, marker='o', label="Golang")

# Set labels for the axes
plt.xlabel('Number of Elements')
plt.ylabel('Time in ms')

# Set title for the plot
plt.title('Bubble Sort Performance')

# Show the plot
plt.show()
