# %%
import matplotlib.pyplot as plt

# %%
python = [[100, 180.96], [1000, 1987.70], [2000, 5141.50], [3000, 8063.79], [4000, 8466.01], [5000, 11208.30], [6000, 13362.17], [7000, 15561.34], [8000, 18497.23], [9000, 19434.93], [10000, 24341.34], [20000, 50086.26], [30000, 105674.74], [40000, 101590.87], [50000, 129616.98]]

# %%
CPP = [[100, 6.999], [1000, 5.999], [2000, 6.000], [3000, 6.000], [4000, 6.999], [5000, 6.997], [6000, 7.000], [7000, 8.999], [8000, 8.001], [9000, 7.995], [10000, 6.999], [20000, 7.999], [30000, 10.998], [40000, 12.999], [50000, 13.999]]

# %%
Golang = [[100, 49.239], [1000, 8.022], [2000, 75.112], [3000, 65.534], [4000, 72.883], [5000, 85.773], [6000, 11.661], [7000, 97.591], [8000, 9.059], [9000, 92.918], [10000, 103.912], [20000, 83.727], [30000, 132.773], [40000, 177.862], [50000, 117.973]]

# %%
x_valuesP = [point[0] for point in python]
y_valuesP = [point[1] for point in python]

x_valuesC = [point[0] for point in CPP]
y_valuesC = [point[1] for point in CPP]

x_valuesG = [point[0] for point in Golang]
y_valuesG = [point[1] for point in Golang]


plt.plot(x_valuesP, y_valuesP, marker='o', label="Python")
plt.plot(x_valuesC, y_valuesC, marker='x', label="C++")
plt.plot(x_valuesG, y_valuesG, marker='o', label="Golang")

# Set labels for the axes
plt.xlabel('Number of Elements')
plt.ylabel('Time in ms')

# Set title for the plot
plt.title('Quick Sort Performance')

# Show the plot
plt.show()
