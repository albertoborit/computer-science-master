# %%
import matplotlib.pyplot as plt

# %%
python = [[100, 189], [1000, 2819], [2000, 6730], [3000, 8579], [4000, 11979], [5000, 14558], [6000, 17457], [7000, 43859], [8000, 28236], [9000, 32416], [10000, 34692], [20000, 100215], [30000, 120968], [40000, 190151], [50000, 235293]]

# %%
CPP = [[100, 0], [1000, 0], [2000, 0], [3000, 0], [4000, 0], [5000, 0], [6000, 0.998], [7000, 0.999], [8000, 0.999], [9000, 0.999], [10000, 1.997], [20000, 3], [30000, 5], [40000, 7], [50000, 8]]

# %%
Golang = [[100, 0], [1000, 0], [2000, 0], [3000, 0], [4000, 0.00528], [5000, 0.00531], [6000, 0.00524], [7000, 0.00528], [8000, 0.00525], [9000, 0.00521], [10000, 0.6], [20000, 0.00535], [30000, 1.065], [40000, 1.7], [50000, 2.11]]

# %%
x_valuesP = [point[0] for point in python]
y_valuesP = [point[1] for point in python]

x_valuesC = [point[0] for point in CPP]
y_valuesC = [point[1] for point in CPP]

x_valuesG = [point[0] for point in Golang]
y_valuesG = [point[1] for point in Golang]


plt.plot(x_valuesP, y_valuesP, marker='o', label="Python")
plt.plot(x_valuesC, y_valuesC, marker='x', label="C++")
plt.plot(x_valuesG, y_valuesG, marker='o', label="Golang")

# Set labels for the axes
plt.xlabel('Number of Elements')
plt.ylabel('Time in ms')

# Set title for the plot
plt.title('Binary Tree Sort Performance')

# Show the plot
plt.show()
